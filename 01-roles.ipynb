# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("API_KEY"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Compreendendo os Roles

# %% [markdown]
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# **LLMs (Large Language Models) – Explicação resumida**
#
# São modelos de inteligência artificial baseados em redes neurais profundas que foram treinados com enormes volumes de texto (bilhões de palavras). Durante o treinamento, eles aprendem a prever a próxima palavra (ou token) a partir do contexto anterior, capturando padrões linguísticos, fatos, estilos e até raciocínios simples.
#
# - **Escala:** “Large” refere‑se tanto ao número de parâmetros (geralmente de centenas de milhões a centenas de bilhões) quanto à quantidade de dados usados.
# - **Funcionamento:** Recebem um texto de entrada, processam-no em várias camadas de atenção e retornam uma probabilidade para cada palavra possível; a palavra com maior probabilidade é escolhida (ou amostrada) como saída.
# - **Aplicações:** geração de texto, tradução, resumo, respostas a perguntas, assistência de programação, chatbots, entre outras tarefas de processamento de linguagem natural.
#
# Em resumo, as LLMs são “cérebro de texto” treinados em escala massiva para compreender e gerar linguagem humana de forma bastante fluente.

# %% [markdown]
# ### Definindo um comportamento para modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# Large Language Models (LLMs) são modelos de inteligência artificial baseados principalmente em arquiteturas **transformer** que foram treinados em **gigantescos volumes de texto** (bilhões a trilhões de palavras). Esse treinamento permite que eles:
#
# 1. **Entendam o contexto** de sequências de palavras, capturando relações sintáticas e semânticas.
# 2. **Gerem texto coerente** em diversos estilos, idiomas e domínios, respondendo perguntas, resumindo, traduzindo, entre outras tarefas.
# 3. **Se adaptem** a novas tarefas com pouca ou nenhuma re‑treinamento (aprendizado por “few‑shot” ou “zero‑shot”).
#
# Em resumo, uma LLM é um modelo de linguagem de grande escala que, graças ao volume de dados e à capacidade de processamento, consegue produzir e compreender linguagem natural de forma surpreendentemente avançada.

# %% [markdown]
# ### Controlando Resposta do Modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma clara e objetiva."
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        },
        {
            "role": "assistant",
            "content": "LLMs com baixa latência permitem respostas mais rápidas, o que melhora a experiência do usuário."
        },
        {
            "role": "user",
            "content": "Pode dar exemplos de aplicações práticas?"
        }
    ],
    model="openai/gpt-oss-120b",
)

print(chat_completion.choices[0].message.content)
# Out:
# **Aplicações práticas que dependem de LLMs de baixa latência**
#
# | Área | Exemplo de aplicação | Por que a latência baixa é crítica |
# |------|----------------------|-------------------------------------|
# | **Assistentes de voz** | Alexa, Google Assistant, Siri | Respostas em < 200 ms evitam interrupções na conversação e mantêm a sensação de “diálogo natural”. |
# | **Chatbots de atendimento** | Suporte ao cliente em sites de e‑commerce, help‑desks bancários | Respostas quase instantâneas (≤ 300 ms) reduzem a taxa de abandono da conversa e aumentam a satisfação do usuário. |
# | **Tradução simultânea** | Ferramentas de legendas ao vivo, dispositivos de tradução portátil | A latência deve ser < 100 ms para que a fala original e a tradução ocorram praticamente ao mesmo tempo, permitindo comunicação fluida. |
# | **Autocompletar e sugestão de código** | GitHub Copilot, IDEs inteligentes | Desenvolvedores esperam sugestões em < 150 ms; qualquer atraso interrompe o fluxo de programação. |
# | **Sistemas de recomendação em tempo real** | Recomendação de produtos enquanto o usuário navega, playlists dinâmicas | Decisões em < 200 ms evitam que o usuário perceba “lento” e aumentam a taxa de cliques/conversão. |
# | **Jogos e simulações** | NPCs que conversam com o jogador, diálogos dinâmicos em RPGs | A latência acima de ~ 250 ms rompe a imersão; respostas rápidas mantêm a jogabilidade fluida. |
# | **Análise de dados e dashboards interativos** | Consultas em linguagem natural sobre métricas empresariais | Usuários de BI esperam respostas em < 500 ms; caso contrário, recorrem a consultas pré‑processadas. |
# | **Aplicações críticas de segurança** | Detecção de comandos maliciosos em sistemas de controle, filtragem de conteúdo em tempo real | Delays acima de 100 ms podem gerar risco de exploração ou falhas de mitigação. |
# | **Realidade aumentada / virtual** | Legendas automáticas, tutoriais contextuais em AR | A sincronização visual/áudio exige latência < 100 ms para não causar desconforto. |
# | **Automação de processos robóticos (RPA)** | Bot que interpreta e executa instruções em linguagem natural | Cada ciclo de decisão deve ser rápido (< 300 ms) para manter a eficiência do fluxo de trabalho. |
#
# ### Por que a baixa latência é tão importante?
# 1. **Experiência do usuário** – Respostas rápidas mantêm a conversa fluida e evitam frustração.
# 2. **Engajamento e conversão** – Em e‑commerce ou serviços, cada segundo de espera pode reduzir drasticamente a taxa de cliques e a finalização de compra.
# 3. **Segurança** – Em contextos críticos (detecção de ameaças, controle de dispositivos), atrasos podem impedir intervenções oportunas.
# 4. **Imersão** – Em jogos, AR/VR ou comunicação ao vivo, latências perceptíveis quebram a sensação de presença.
# 5. **Produtividade** – Para desenvolvedores, analistas ou operadores, respostas instantâneas aceleram fluxos de trabalho e reduzem interrupções.
#
# ### Estratégias para alcançar baixa latência
# - **Modelos otimizados**: quantização, poda e uso de arquiteturas menores (e.g., DistilBERT, Llama‑2‑7B) quando a precisão pode ser sacrificada levemente.
# - **Infraestrutura de borda**: deploy em servidores edge ou dispositivos locais para reduzir a distância de rede.
# - **Batching dinâmico**: agrupar requisições que chegam quase simultaneamente sem introduzir delays perceptíveis.
# - **Cache de inferência**: armazenar respostas para consultas frequentes ou resultados de pré‑cálculo.
# - **Compilação de modelo**: usar compiladores como TVM, ONNX Runtime, TensorRT para acelerar a inferência em hardware específico (GPU, TPU, ASIC).
#
# Esses exemplos mostram como a latência baixa deixa os LLMs realmente úteis em situações onde o tempo de resposta é tão valioso quanto a qualidade da resposta.

# %% [markdown]
# ### Usando System Prompt Refinados

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "Você é um especialista em Inteligência Artificial focado em explicar conceitos "
                "de forma clara, estruturada e prática. Sempre inicie suas respostas com um "
                "resumo em até 3 linhas, depois detalhe com exemplos reais e aplicações no mundo "
                "dos negócios e tecnologia. Evite termos excessivamente técnicos sem explicação "
                "e, quando necessário, use analogias simples. "
                "Se o usuário pedir código, forneça exemplos em Python bem comentados."
            ),
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        }
    ],
    model="openai/gpt-oss-120b",
)

print(chat_completion.choices[0].message.content)
# Out:
# **Resumo (até 3 linhas)**
# LLMs com baixa latência respondem quase que instantaneamente, o que é crucial para manter a fluidez da experiência do usuário, suportar decisões em tempo real e reduzir custos operacionais em ambientes de alta demanda.
#
# ---
#
# ## Por que a latência baixa importa?
#
# | Aspecto | Como a latência afeta | Consequência de baixa latência |
# |--------|----------------------|--------------------------------|
# | **Experiência do usuário** | Usuários percebem atrasos como lentidão ou falha do sistema. | Interações fluidas, maior satisfação e retenção. |
# | **Decisões críticas** | Em finanças, saúde ou manufatura, decisões precisam ser tomadas em segundos ou menos. | Ações mais rápidas, risco reduzido, vantagem competitiva. |
# | **Escalabilidade e custo** | Servidores ociosos enquanto esperam respostas aumentam o custo de infraestrutura. | Mais requisições por segundo com o mesmo hardware, menor gasto com cloud. |
# | **Integração em tempo real** | Chatbots, assistentes de voz ou sistemas de recomendação exigem respostas imediatas. | Integrações suaves, sem necessidade de “pré‑carregamento” ou buffering. |
#
# ### Analogia simples
# Imagine um atendente de caixa em um supermercado: se ele demora para digitar o preço, a fila cresce e os clientes ficam irritados. Um modelo de linguagem com baixa latência age como um caixa super rápido, processando cada cliente em tempo quase zero, mantendo a fila curta e o fluxo constante.
#
# ## Exemplos reais no mundo dos negócios
#
# 1. **Assistentes de voz em dispositivos domésticos**
#    *Caso*: Alexa, Google Assistant e Siri precisam entender e responder em menos de 300 ms para que a conversa pareça natural.
#    *Impacto*: Respostas rápidas mantêm a sensação de “conversa humana”, evitando que o usuário repita a pergunta ou desista da interação.
#
# 2. **Chatbots de suporte ao cliente**
#    *Caso*: Uma operadora de telecomunicações implementou um chatbot que resolve 60 % das solicitações na primeira interação.
#    *Impacto*: Redução de 30 % no tempo médio de atendimento e aumento da taxa de resolução no primeiro contato, gerando economia de custos com call centers.
#
# 3. **Plataformas de trading algorítmico**
#    *Caso*: Um fundo de investimento usa um LLM para analisar notícias e gerar sinais de compra/venda em tempo real.
#    *Impacto*: Cada milissegundo conta; latência baixa permite que o modelo influencie decisões antes que o mercado ajuste os preços, aumentando retornos.
#
# 4. **Sistemas de recomendação em e‑commerce**
#    *Caso*: Um marketplace exibe recomendações de produtos enquanto o usuário navega.
#    *Impacto*: Respostas em < 200 ms evitam interrupções na jornada de compra, elevando a taxa de conversão em até 5 %.
#
# 5. **Aplicações industriais (IoT)**
#    *Caso*: Um robô colaborativo usa um LLM para interpretar comandos de linguagem natural e ajustar seu comportamento em tempo real.
#    *Impacto*: Reduz o tempo de configuração de máquinas e aumenta a segurança ao evitar atrasos na interpretação de instruções críticas.
#
# ## Como alcançar baixa latência em LLMs
#
# 1. **Modelos otimizados**
#    - **Quantização**: reduzir a precisão dos números (por exemplo, de 32‑bits para 8‑bits) diminui o tamanho do modelo e acelera a inferência.
#    - **Pruning (poda)**: remover neurônios menos relevantes para tornar o modelo mais enxuto sem perder muita acurácia.
#
# 2. **Infraestrutura adequada**
#    - **Hardware especializado**: GPUs de última geração, TPUs ou aceleradores de inferência (por ex., Intel Habana, AWS Inferentia).
#    - **Edge computing**: rodar o modelo próximo ao usuário (no próprio dispositivo ou em servidores regionais) reduz a latência de rede.
#
# 3. **Arquitetura de implantação**
#    - **Serviços de inferência em lote vs. streaming**: para respostas instantâneas, use APIs de streaming que enviam tokens assim que são gerados.
#    - **Cache de resultados frequentes**: armazenar respostas para perguntas recorrentes reduz chamadas ao modelo.
#
# 4. **Pipeline de pré‑processamento rápido**
#    - Simplificar tokenização e normalização de texto; usar bibliotecas otimizadas como `tokenizers` da Hugging Face.
#
# ## Benefícios estratégicos para a sua empresa
#
# - **Retenção de clientes**: interações rápidas aumentam a confiança e lealdade.
# - **Eficiência operacional**: menos recursos computacionais por consulta = menor conta de cloud.
# - **Vantagem competitiva**: ser o primeiro a responder a eventos do mercado ou a demandas dos usuários.
# - **Escalabilidade**: um modelo de baixa latência pode suportar picos de tráfego sem precisar duplicar servidores.
#
# ## Checklist rápido para avaliar a latência do seu LLM
#
# 1. **Tempo médio de resposta (latência) < 300 ms?**
# 2. **Variabilidade (jitter) está dentro de limites aceitáveis?**
# 3. **O modelo roda em hardware adequado (GPU/TPU/Inferentia)?**
# 4. **Existe camada de cache para consultas repetitivas?**
# 5. **A tokenização e o pós‑processamento são otimizados?**
#
# Se alguma dessas respostas for “não”, há oportunidade de melhorar a experiência e reduzir custos.
#
# ---
#
# ### Conclusão
# LLMs com baixa latência são mais que um luxo de “resposta rápida”: eles são alavancas estratégicas que afetam a satisfação do usuário, a capacidade de tomar decisões em tempo real, o custo da infraestrutura e a competitividade no mercado. Investir em otimizações de modelo, hardware e arquitetura de implantação garante que sua empresa aproveite plenamente o potencial da IA generativa.
